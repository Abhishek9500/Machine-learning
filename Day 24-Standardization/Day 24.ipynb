# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df=df.iloc[:,2:]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['Purchased'],axis=1)
y=df['Purchased']
x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.3,
    random_state=0
)

# %%
x_train.shape,x_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
## fit the scale and train set, it will learn the parameter
scaler.fit(x_train)

## transform train and test data set
x_train_scaled= scaler.transform(x_train)
x_test_scaled= scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
x_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
## x_train and x_test is a numpy array Beacuse transform return numpy array 
## first of all convert it into dataframe

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
x_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
x_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# # Effect of Scaling

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1,ax2)= plt.subplots(ncols=2,figsize=(12,5))

# Before Scaling 
ax1.set_title("Before Scaleing")
sns.kdeplot(x_train['Age'],ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)

# After Scaling

ax2.set_title("After Scaling")
sns.kdeplot(x_train_scaled['Age'],ax=ax2)
sns.kdeplot(x_train_scaled['EstimatedSalary'],ax=ax2)

plt.show()

# %% [markdown]
# # Comparison of Distributions

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Age Before Scaling Data')
sns.kdeplot(x_train['Age'],ax=ax1)

ax2.set_title('Age After Scaling Data')
sns.kdeplot(x_train_scaled['Age'],ax=ax2)

plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)

ax2.set_title('Salary Distribution Agter Scaling')
sns.kdeplot(x_train['EstimatedSalary'],ax=ax2)

plt.show()

# %% [markdown]
# # Why Scaling is Important

# %%
# Many machine learning algorithms calculate distance or use gradients. If one feature has much larger values, it can dominate the calculations.

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr_scaled=LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr_scaled.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
y_pred_scaled=lr_scaled.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual Score",accuracy_score(y_test,y_pred))
print("Scaled Score",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual Score 0.875
# Scaled Score 0.8666666666666667

# %% [markdown]
# # Effect of Outlier

# %%
# An outlier is a data point that is significantly different from the rest of the data.
# Example
# Most salaries are between ₹20,000 and ₹80,000, but one person earns ₹10,00,000.

# %%
# Create the new data as a separate DataFrame
new_data = pd.DataFrame({
    'Age': [5, 90, 95], 
    'EstimatedSalary': [1000, 250000, 350000], 
    'Purchased': [0, 1, 1]
})

# Concatenate the original df with the new_data
df = pd.concat([df, new_data], ignore_index=True)

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
plt.scatter(df['Age'],df['EstimatedSalary'])

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['Purchased'],axis=1)
y=df['Purchased']
x_tran,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.3,
    random_state=0
)

# %%
x_train.shape,x_test.shape
# Out:
# ((280, 2), (121, 2))

# %%
from sklearn.preprocessing import StandardScaler

Scaler = StandardScaler()


# fit the scaler data
Scaler.fit(x_train)

# transform data
x_test_scaled= Scaler.transform(x_test)
x_train_scaled=Scaler.transform(x_train)

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
fig , (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")

ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")

plt.show()
