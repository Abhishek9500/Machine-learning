# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv('titanic_toy.csv')

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
x.head()
# Out:
#     Age     Fare  Family
# 0  22.0   7.2500       1
# 1  38.0  71.2833       1
# 2  26.0   7.9250       0
# 3  35.0  53.1000       1
# 4  35.0   8.0500       0

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=0
)

# %%
x_train.head()
# Out:
#       Age     Fare  Family
# 140   NaN  15.2458       2
# 439  31.0  10.5000       0
# 817  31.0  37.0042       2
# 378  20.0      NaN       0
# 491  21.0   7.2500       0

# %%
x_train['Age_99']=x_train['Age'].fillna(99)
x_train['Age_minus1']=x_train['Age'].fillna(-1)

x_train['Fare_99']=x_train['Fare'].fillna(99)
x_train['Fare_minus1']=x_train['Fare'].fillna(-1)

# %%
x_train.head()
# Out:
#       Age     Fare  Family  Age_99  Age_minus1  Fare_99  Fare_minus1
# 140   NaN  15.2458       2    99.0        -1.0  15.2458      15.2458
# 439  31.0  10.5000       0    31.0        31.0  10.5000      10.5000
# 817  31.0  37.0042       2    31.0        31.0  37.0042      37.0042
# 378  20.0      NaN       0    20.0        20.0  99.0000      -1.0000
# 491  21.0   7.2500       0    21.0        21.0   7.2500       7.2500

# %%
print("Original Age Variable Variance = ", x_train['Age'].var())
print("Age Varianve after 99 wala imputation = ",x_train['Age_99'].var())
print("Age Variance after minus 1 wala imputation = ",x_train['Age_minus1'].var())

print("Original Fare Variable Variance = ", x_train['Fare'].var())
print("Fare Varianve after 99 wala imputation = ",x_train['Fare_99'].var())
print("Fare Variance after minus 1 wala imputation = ",x_train['Fare_minus1'].var())
# Out:
# Original Age Variable Variance =  213.7165085187575
# Age Varianve after 99 wala imputation =  934.1249575238231
# Age Variance after minus 1 wala imputation =  321.6688109349073
# Original Fare Variable Variance =  2574.352620663723
# Fare Varianve after 99 wala imputation =  2666.685517819386
# Fare Variance after minus 1 wala imputation =  2489.213857315901

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

## original variable distribution
x_train['Age'].plot(kind='kde',ax=ax)

## Variable imputed with 99
x_train['Age_99'].plot(kind='kde',ax=ax,color='red')

## variable imputed with minus 1
x_train['Age_minus1'].plot(kind='kde',ax=ax,color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

## original variable distribution
x_train['Fare'].plot(kind='kde',ax=ax)

## Variable imputed with 99
x_train['Fare_99'].plot(kind='kde',ax=ax,color='red')

## variable imputed with minus 1
x_train['Fare_minus1'].plot(kind='kde',ax=ax,color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
x_train.cov()
# Out:
#                     Age         Fare     Family      Age_99  Age_minus1  \
# Age          213.716509    84.480223  -6.393469  213.716509  213.716509
# Fare          84.480223  2574.352621  17.050423  -49.762911  119.548363
# Family        -6.393469    17.050423   2.770177   -5.506430   -4.956484
# Age_99       213.716509   -49.762911  -5.506430  934.124958 -167.301760
# Age_minus1   213.716509   119.548363  -4.956484 -167.301760  321.668811
# Fare_99       80.149052  2574.352621  15.460768  -57.835735  118.455613
# Fare_minus1   79.287836  2574.352621  16.435815  -41.740249  110.313200
#
#                  Fare_99  Fare_minus1
# Age            80.149052    79.287836
# Fare         2574.352621  2574.352621
# Family         15.460768    16.435815
# Age_99        -57.835735   -41.740249
# Age_minus1    118.455613   110.313200
# Fare_99      2666.685518  2318.710841
# Fare_minus1  2318.710841  2489.213857

# %%
x_train.corr()
# Out:
#                   Age      Fare    Family    Age_99  Age_minus1   Fare_99  \
# Age          1.000000  0.106334 -0.295318  1.000000    1.000000  0.100549
# Fare         0.106334  1.000000  0.198661 -0.031926    0.130702  1.000000
# Family      -0.295318  0.198661  1.000000 -0.108247   -0.166041  0.179884
# Age_99       1.000000 -0.031926 -0.108247  1.000000   -0.305206 -0.036644
# Age_minus1   1.000000  0.130702 -0.166041 -0.305206    1.000000  0.127898
# Fare_99      0.100549  1.000000  0.179884 -0.036644    0.127898  1.000000
# Fare_minus1  0.102325  1.000000  0.197928 -0.027373    0.123280  0.899973
#
#              Fare_minus1
# Age             0.102325
# Fare            1.000000
# Family          0.197928
# Age_99         -0.027373
# Age_minus1      0.123280
# Fare_99         0.899973
# Fare_minus1     1.000000

# %% [markdown]
# ## Using Sklearn

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=0
)

# %%
imputer1 = SimpleImputer(strategy='constant',fill_value=99)
imputer2 = SimpleImputer(strategy='constant',fill_value=999)

# %%
trf = ColumnTransformer([
    ('imputer1',imputer1,['Age']),
    ('imputer2',imputer2,['Fare'])
],remainder='passthrough')

# %%
trf.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1',
#                                  SimpleImputer(fill_value=99,
#                                                strategy='constant'),
#                                  ['Age']),
#                                 ('imputer2',
#                                  SimpleImputer(fill_value=999,
#                                                strategy='constant'),
#                                  ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([99], dtype=object)

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([999], dtype=object)

# %%
x_train=trf.transform(x_train)
x_test=trf.transform(x_test)

# %%
x_train
# Out:
# array([[99.    , 15.2458,  2.    ],
#        [31.    , 10.5   ,  0.    ],
#        [31.    , 37.0042,  2.    ],
#        ...,
#        [99.    ,  7.7333,  0.    ],
#        [36.    , 17.4   ,  1.    ],
#        [60.    , 39.    ,  2.    ]], shape=(712, 3))
